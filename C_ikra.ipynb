# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __KM IKRA__
#
# Assistant Professor

# %% [markdown]
# _I am interested in data science because i would like to involve in data science project which imapact our day to day life_

# %% [markdown]
# ### My code is to calculate the sum of element in list

# %%
a=[1,2,3,4]
n=len(a)
sum=0
for i in range(n):
    sum=sum+a[i]
print(sum)
# Out:
# 10

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
